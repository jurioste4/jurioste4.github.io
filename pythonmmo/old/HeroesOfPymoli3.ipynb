# %% [markdown]
# ### Heroes Of Pymoli Data Analysis

# %%
# Dependencies and Setup
import pandas as pd
import numpy as np
import os, sys
# File to Load (Remember to Change These)
path = "Resources/data.csv"

# Read Purchasing File and store into Pandas data frame
purchase_data = pd.read_csv(path)
purchase_data.head(10)
# Out:
#    Purchase ID             SN  Age                 Gender  Item ID  \
# 0            0        Lisim78   20                   Male      108
# 1            1    Lisovynya38   40                   Male      143
# 2            2     Ithergue48   24                   Male       92
# 3            3  Chamassasya86   24                   Male      100
# 4            4      Iskosia90   23                   Male      131
# 5            5        Yalae81   22                   Male       81
# 6            6      Itheria73   36                   Male      169
# 7            7    Iskjaskst81   20                   Male      162
# 8            8      Undjask33   22                   Male       21
# 9            9    Chanosian48   35  Other / Non-Disclosed      136
#
#                                    Item Name  Price
# 0  Extraction, Quickblade Of Trembling Hands   3.53
# 1                          Frenzied Scimitar   1.56
# 2                               Final Critic   4.88
# ...

# %%
city_total = purchase_data.groupby(['Gender']).agg({
                                                   'Price':'sum',
                                                   total_gender/total * 100
                                                   'SN':'count'})
city_total
# Out:
#   File "<ipython-input-38-afd85bf51d1d>", line 4
#     'SN':'count'})
#        ^
# SyntaxError: invalid syntax

# %%
total = purchase_data['SN'].count()
total_money = gender_total["Price"].sum()
test = gender_total.nunique()["Gender"]
test
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Gender'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-32-7cf76b480b73> in <module>
#       1 total = purchase_data['SN'].count()
# ...

# %%
gender_total = purchase_data.groupby("Gender")
total_gender= gender_total.nunique( )["SN"]
total_money = gender_total["Price"].count()
player_percentage = total_gender / total * 100


total_gender
# Out:
# Gender
# Female                    81
# Male                     484
# Other / Non-Disclosed     11
# Name: SN, dtype: int64

# %%
# df = total_gender.to_frame().reset_index()
test = pd.DataFrame(dict(player_percentage = player_percentage, total_money = total_money), index=player_percentage.index)
test
# pd.DataFrame(data=dict(s1=s1, s2=s2), index=s1.index)


# gender = pd.DataFrame( 
#    {"gender users":total_gender,
#    "percentage":player_percentage,
#    " sales":total_money})

# gender
# Out:
#                        player_percentage  total_money
# Gender
# Female                         10.384615          113
# Male                           62.051282          652
# Other / Non-Disclosed           1.410256           15

# %%
df = total_gender.to_frame().reset_index()
# list(gender.columns.values)
df
# Out:
#                   Gender   SN
# 0                 Female   81
# 1                   Male  484
# 2  Other / Non-Disclosed   11

# %%
from io import StringIO
import json
    

buff=StringIO()
    #df is your DataFrame
gender_bar.to_json(path_or_buf=buff,orient=index)
dfJson=json.loads(buff)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-9c805258967e> in <module>
#       5 buff=StringIO()
#       6     #df is your DataFrame
# ----> 7 gender_bar.to_json(path_or_buf=buff,orient=index)
#       8 dfJson=json.loads(buff)
#
# NameError: name 'index' is not defined

# %%
 with open('Resources/gender_total.json','w') as f:
    f.write(gender_bar.to_json(orient = "index"))

# %% [markdown]
# ## Player Count

# %% [markdown]
# * Display the total number of players

# %%
total = purchase_data['SN'].count()

print("Total number of Players",total)
# Out:
# Total number of Players 780

# %% [markdown]
# * data frame for total unique items

# %%
purchase_item_name = len(purchase_data["Item Name"].unique())

# purchase_average = purchase_data["Price"].mean()

# purchase_total = purchase_data["Price"].sum()

# summary_table = pd.DataFrame(
#     {"Total Unique Item": purchase_item_name,
#     "Average Item Price": [purchase_average],
#     "Total Purchase Price": [purchase_total]})
# summary_table
purchase_item_name
# Out:
# 179

# %% [markdown]
# ## Gender Demographics

# %%
gender_total = purchase_data.groupby("Gender")["SN"].nunique() / total * 100

gender_total


# pie Graph here
# Out:
# Gender
# Female                   10.384615
# Male                     62.051282
# Other / Non-Disclosed     1.410256
# Name: SN, dtype: float64

# %% [markdown]
# ## Purchasing Analysis (Gender)

# %% [markdown]
# * Run basic calculations to obtain purchase count, avg. purchase price, avg. purchase total per person etc. by gender
#
#
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display the summary data frame

# %%
#count_buy = gender_total["Purchase ID"].count()

#price_avg = gender_total["Price"].mean()
price_total = gender_total["Price"].agg([np.mean, np.sum , np.std,len])
price_total
# Out:
#                            mean      sum       std    len
# Gender
# Female                 3.203009   361.94  1.158194  113.0
# Male                   3.017853  1967.64  1.175625  652.0
# Other / Non-Disclosed  3.346000    50.19  0.883813   15.0

# %% [markdown]
# ## Age Demographics

# %% [markdown]
# * Establish bins for ages
#
#
# * Categorize the existing players using the age bins. Hint: use pd.cut()
#
#
# * Calculate the numbers and percentages by age group
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: round the percentage column to two decimal points
#
#
# * Display Age Demographics Table

# %%
Age_bin = [0,10,14,19,24,29,34,41,100]
group_names = ["<10", "10-14", "15-19", "20-24", "25-29", "30-34", "35-39", "40+"]

purchase_data["age group"] = pd.cut(purchase_data["Age"],Age_bin,labels=group_names )
purchase_data


age_costgroup = purchase_data.groupby("age group")

age_count = age_costgroup["SN"].nunique()

Percentage = (age_count/total) * 100

Playercount_byage = pd.DataFrame({"Player Percentage": Percentage,"Count": age_count})

Playercount_byage.head()
# Out:
#            Player Percentage  Count
# age group
# <10                 3.076923     24
# 10-14               1.923077     15
# 15-19              13.717949    107
# 20-24              33.076923    258
# 25-29               9.871795     77

# %% [markdown]
# ## Purchasing Analysis (Age)

# %% [markdown]
# * taken the information above to display based on total

# %%
total_purch_age = age_costgroup["Purchase ID"].count()
average_purch = age_costgroup["Price"].mean()
total_age_purch = age_costgroup["Price"].sum()

purchase_per_age_avg = (total_age_purch/total_purch_age) 

Age_Analysis_pd = pd.DataFrame({"Player Percent": purchase_per_age_avg,
                              "count": total_purch_age })

Age_Analysis_pd.head()
# Out:
#            Player Percent  count
# age group
# <10              3.405000     32
# 10-14            2.681579     19
# 15-19            3.035956    136
# 20-24            3.052219    365
# 25-29            2.900990    101

# %%
total_age_purch
# Out:
# age group
# <10       108.96
# 10-14      50.95
# 15-19     412.89
# 20-24    1114.06
# 25-29     293.00
# 30-34     214.00
# 35-39     170.92
# 40+        14.99
# Name: Price, dtype: float64

# %%
#spender_count = top_spender["Count"].count()

# %% [markdown]
# ## Top Spenders

# %%
#group the data frame purchase_data and group by the SN colum
top_spender =purchase_data.groupby("SN")
# then do a count,mean and sum of colums below .. 
spender_count = top_spender["Purchase ID"].count()
avg_spender = top_spender["Price"].mean()

spender_total = top_spender["Price"].sum()
#place the outputs of the three colums in to a data frame 
Most_spenders_pd = pd.DataFrame({"Count": spender_count,
                                 "Avg spent": avg_spender,
                                 "Spender_total": spender_total})



#now I have top spenders with total itams payed for and total spent 
#this is intresting as some spent more but bout less items 
Most_spenders_pd.sort_values(by='Spender_total',ascending=False)
# Out:
#                Count  Avg spent  Spender_total
# SN
# Lisosia93          5   3.792000          18.96
# Idastidru52        4   3.862500          15.45
# Chamjask73         3   4.610000          13.83
# Iral74             4   3.405000          13.62
# Iskadarya95        3   4.366667          13.10
# Ilarin91           3   4.233333          12.70
# Ialallo29          3   3.946667          11.84
# Tyidaim51          3   3.943333          11.83
# Lassilsala30       3   3.836667          11.51
# Chadolyla44        3   3.820000          11.46
# Iri67              3   3.790000          11.37
# Inguron55          3   3.703333          11.11
# Siallylis44        3   3.456667          10.37
# Saistyphos30       3   3.443333          10.33
# Phyali88           3   3.433333          10.30
# Strithenu87        3   3.393333          10.18
# Lisim78            3   3.340000          10.02
# Haillyrgue51       3   3.166667           9.50
# Phistym51          2   4.750000           9.50
# ...

# %% [markdown]
# ## Most Popular Items

# %% [markdown]
# *pulled from purchase_data only three coulum I needed with in a valuble called most
#
# *did a group by with in that for item ID and item name
#
# *then .count and .sum for both price callem with in the groupby varalble claled item_grup
#
# *then I dived the sum and count groups to get real cost
#
# *created a data frame

# %%
most = purchase_data[["Item ID", "Item Name", "Price"]]
item_grup = most.groupby(["Item ID", "Item Name"])  

item_count = item_grup["Price"].count()

Item_price = item_grup["Price"].sum()

real_cost = Item_price/item_count


Most_popular_Stuff = pd.DataFrame({"count of items": item_count,
                                  "item price": Item_price,
                                  "Real cost": real_cost})

Most_popular_Stuff.head()
# Out:
#                             count of items  item price  Real cost
# Item ID Item Name
# 0       Splinter                         4        5.12       1.28
# 1       Crucifer                         3        9.78       3.26
# 2       Verdict                          6       14.88       2.48
# 3       Phantomlight                     6       14.94       2.49
# 4       Bloodlord's Fetish               5        8.50       1.70

# %% [markdown]
# ## Most Profitable Items

# %% [markdown]
# * sorted the order of above data frame by item price
#
#
# * and placed it in a data frame

# %%
most_profit = Most_popular_Stuff.sort_values(["item price"], ascending=False)

most_profit.head()
# Out:
#                                                       count of items  \
# Item ID Item Name
# 178     Oathbreaker, Last Hope of the Breaking Storm              12
# 82      Nirvana                                                    9
# 145     Fiery Glass Crusader                                       9
# 92      Final Critic                                               8
# 103     Singed Scalpel                                             8
#
#                                                       item price  Real cost
# Item ID Item Name
# 178     Oathbreaker, Last Hope of the Breaking Storm       50.76       4.23
# 82      Nirvana                                            44.10       4.90
# 145     Fiery Glass Crusader                               41.22       4.58
# 92      Final Critic                                       39.04       4.88
# 103     Singed Scalpel                                     34.80       4.35
